# %%
#---- -2 ---- -1 ---- 0 ---- 1 ---- 2 ----

# %%
import numpy as np
from numpy.random import randn

# %%
randn()
# Out:
# -0.40760241863102054

# %% [markdown]
# ---

# %%
#---- -2 ---- -1 ---- 0 ---- 1 ---- 2 ----
answer = None
x = randn()
if x > 1:
    answer = "Greater than 1"
print(x)
print(answer)
# Out:
# -1.361377426768372
# None

# %% [markdown]
# ---

# %%
#---- -2 ---- -1 ---- 0 ---- 1 ---- 2 ----
#Nested statements
answer = None
x = randn()
if x > 1:
    answer = "Greater than 1"
else:
    if x >= -1:
        answer = "Between -1 and 1"
    else:
        answer = "Less than -1"
print(x)
print(answer)
# Out:
# 1.1308267963114835
# Greater than 1

# %% [markdown]
# ---

# %%
#---- -2 ---- -1 ---- 0 ---- 1 ---- 2 ----
#Chained Statements
answer = None
x = randn()
if x > 1:
    answer = "Greater than 1"
elif x >= -1:
    answer = "Between -1 and 1"
else: 
    answer = "Less than -1"
print(x)
print(answer)
# Out:
# -0.5450848598088364
# Between -1 and 1
