# %%
import numpy as np
from numpy.random import randn

N = 100000000
counter = 0
for i in randn(1000):
    if (i > -1 and i < 1):
        counter = counter + 1
counter/1000
# Out:
# 0.677

# %%
import numpy as np
from numpy.random import randn

N = 10000
counter = 0
for i in randn(N):
    if i > -1 and i < 1:
        counter = counter + 1
counter/N
# Out:
# 0.6871
