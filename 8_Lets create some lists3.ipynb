# %%
w = ['a', 'b', 'c', 'd', 'e']

# %%
w
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
w[0]
# Out:
# 'a'

# %%
w[1]
# Out:
# 'b'

# %%
w[2]
# Out:
# 'c'

# %%
len(w)
# Out:
# 5

# %%
w
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
#0     1    2    3    4

# %%
#-5   -4   -3   -2   -1

# %%
w[-1] #different behaviour to R
# Out:
# 'e'

# %%
w[-3]
# Out:
# 'c'

# %%
#overwrite values

# %%
w
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
w[2] = 63

# %%
w
# Out:
# ['a', 'b', 63, 'd', 'e']
