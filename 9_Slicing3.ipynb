# %%
letters = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
letters
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
letters[:]
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
letters[2:]
# Out:
# ['C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
letters[:7]
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
letters[2:7]
# Out:
# ['C', 'D', 'E', 'F', 'G']

# %%
letters[-8:7]
# Out:
# ['C', 'D', 'E', 'F', 'G']

# %%
letters[-8:-3]
# Out:
# ['C', 'D', 'E', 'F', 'G']

# %%
#--- Advanced slicing

# %%
letters[2:9:2]
# Out:
# ['C', 'E', 'G', 'I']

# %%
letters
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
letters[::3]
# Out:
# ['A', 'D', 'G', 'J']
