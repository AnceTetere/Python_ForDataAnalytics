# %%
#---- -2 ---- -1 ---- 0 ---- 1 ---- 2 ----

# %%
import numpy as np
from numpy.random import randn

# %%
randn()
# Out:
# -1.6181159393607107

# %% [markdown]
# ---

# %%
#---- -2 ---- -1 ---- 0 ---- 1 ---- 2 ----
answer = None
x = randn()
if x > 1:
    answer = "Greater than 1"
print(x)
print(answer)
# Out:
# 2.3302967019178804
# Greater than 1

# %% [markdown]
# ---

# %%
#---- -2 ---- -1 ---- 0 ---- 1 ---- 2 ----
x = randn()
if x > 1:
    answer = "Greater than 1"
else:
    answer = "Less than 1"
print(x)
print(answer)
# Out:
# -0.2672839277087585
# Less than 1

# %%
#---- -2 ---- -1 ---- 0 ---- 1 ---- 2 ----
#Nested Statements
x = randn()

if x > 1:
    answer = "Greater than 1"
else:
    if x >= -1:
        answer = "Between -1 and 1"
    else:
        answer = "Less than -1"

print(x)
print(answer)
# Out:
# 0.2661619853305932
# Between -1 and 1

# %% [markdown]
# ---

# %%
#---- -2 ---- -1 ---- 0 ---- 1 ---- 2 ----
#Chained Statements
x = randn()

if x > 1:
    answer = "Greater than 1"
elif x >= -1:
    answer = "Between -1 and 1"
else:
    answer = "Less than -1"

print(x)
print(answer)
# Out:
# -1.0352896428849145
# Less than -1
